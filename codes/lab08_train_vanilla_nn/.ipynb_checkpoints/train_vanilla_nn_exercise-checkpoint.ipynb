# %% [markdown]
# # Lab 08: Train vanilla neural network -- exercise
#
#
# # Training a one-layer net on  FASHION-MNIST

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from random import randint
import utils

# %% [markdown]
# ### Download the TRAINING SET (data+labels)

# %%
train_data=torch.load('../data/fashion-mnist/train_data.pt')
train_label=torch.load('../data/fashion-mnist/train_label.pt')
print(train_data.size())
print(train_label.size())
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])

# %% [markdown]
# ### Download the TEST SET (data only)

# %%
test_data=torch.load('../data/fashion-mnist/test_data.pt')
print(test_data.size())
# Out:
# torch.Size([10000, 28, 28])

# %% [markdown]
# ### Make a one layer net class

# %%
class one_layer_net(nn.Module):

    def __init__(self, input_size, output_size):
        super(one_layer_net , self).__init__()
        
        # complete here
        self.linear_layer = nn.Linear(input_size, output_size, bias=True)
        
    def forward(self, x):
        
        x = self.linear_layer(x)# complete here
        p = F.softmax(x, dim=1)# complete here
        
        return p

# %% [markdown]
# ### Build the net

# %%
net=one_layer_net(784,10)
print(net)
# Out:
# one_layer_net(
#   (linear_layer): Linear(in_features=784, out_features=10, bias=True)
# )

# %% [markdown]
# ### Take the 4th image of the test set:

# %%
im= test_data[4]# complete here
utils.show(im)

# %% [markdown]
# ### And feed it to the UNTRAINED network:

# %%
p = net(im.view(1,784))# complete here
print(p)
# Out:
# tensor([[0.0984, 0.1485, 0.1045, 0.0668, 0.0909, 0.1227, 0.0948, 0.1074, 0.0664,
#          0.0995]], grad_fn=<SoftmaxBackward>)

# %% [markdown]
# ### Display visually the confidence scores

# %%
utils.show_prob_fashion_mnist(p)

# %% [markdown]
# ### Train the network (only 5000 iterations) on the train set

# %%
criterion = nn.NLLLoss()
optimizer=torch.optim.SGD(net.parameters() , lr=0.01 )

for iter in range(1,10000):
    
    # choose a random integer between 0 and 59,999 
    # extract the corresponding picture and label
    # and reshape them to fit the network

    idx = randint(1, 60000)    # complete here
    input = train_data[idx].view(1,784)# complete here
    label = train_label[idx].view(1)# complete here


    # feed the input to the net  
    input.requires_grad_()
    prob = net(input)# complete here 
 
    # update the weights (all the magic happens here -- we will discuss it later)
    log_prob=torch.log(prob)
    loss = criterion(log_prob, label)    
    optimizer.zero_grad()       
    loss.backward()
    optimizer.step()

# %% [markdown]
# ### Take the 34th image of the test set:

# %%
im= test_data[34]# complete here
utils.show(im)
test_label=torch.load('../data/fashion-mnist/test_label.pt')
print(test_label[34])
# Out:
# tensor(8)

# %% [markdown]
# ### Feed it to the TRAINED net:

# %%
p = net(im.view(1,784))# complete here
print(p)
# Out:
# tensor([[4.6963e-05, 2.0902e-06, 2.1961e-02, 3.6374e-03, 1.3120e-04, 5.6062e-03,
#          4.4572e-04, 2.1702e-05, 9.6811e-01, 3.9655e-05]],
#        grad_fn=<SoftmaxBackward>)

# %% [markdown]
# ### Display visually the confidence scores

# %%
utils.show_prob_fashion_mnist(prob)

# %% [markdown]
# ### Choose image at random from the test set and see how good/bad are the predictions

# %%
# choose a picture at random
idx=randint(0, 10000-1)
im=test_data[idx]

# diplay the picture
utils.show(im)

# feed it to the net and display the confidence scores
prob =  net( im.view(1,784)) 
utils.show_prob_fashion_mnist(prob)
